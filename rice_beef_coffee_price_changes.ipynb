# %% [markdown]
# <a href="https://colab.research.google.com/github/SANTOSTAVARES/cerial-prices-changes-within-last-30-years/blob/main/rice_beef_coffee_price_changes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/SANTOSTAVARES/cerial-prices-changes-within-last-30-years/e2e6c81777500772decb01e5a3a8aa6c3fc874e6/rice_wheat_corn_prices.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#      Year Month  Price_wheat_ton  Price_rice_ton  Price_corn_ton  \
# 0    1992   Feb           170.12          278.25          113.62
# 1    1992   Mar           161.44          277.20          117.00
# 2    1992   Apr           153.07          278.00          108.52
# 3    1992   May           139.72          274.00          109.64
# 4    1992   Jun           140.36          268.80          110.90
# ..    ...   ...              ...             ...             ...
# 355  2021   Sep           263.60          400.00          235.62
# 356  2021   Oct           334.50          401.00          239.65
# 357  2021   Nov           327.82          400.00          248.72
# 358  2021   Dec           332.06          400.00          264.54
# 359  2022   Jan              NaN          427.00          276.62
#
#      Inflation_rate  Price_wheat_ton_infl  Price_rice_ton_infl  \
# 0             89.59                322.53               527.53
# ...

# %%
df["Year"] = df["Year"].astype(str)

# %%
#df["Period"] = df["Month"] + df["Year"].astype(str)
df["Period"] = df["Month"] + df["Year"]

# %%
df
# Out:
#      Year Month  Price_wheat_ton  Price_rice_ton  Price_corn_ton  \
# 0    1992   Feb           170.12          278.25          113.62
# 1    1992   Mar           161.44          277.20          117.00
# 2    1992   Apr           153.07          278.00          108.52
# 3    1992   May           139.72          274.00          109.64
# 4    1992   Jun           140.36          268.80          110.90
# ..    ...   ...              ...             ...             ...
# 355  2021   Sep           263.60          400.00          235.62
# 356  2021   Oct           334.50          401.00          239.65
# 357  2021   Nov           327.82          400.00          248.72
# 358  2021   Dec           332.06          400.00          264.54
# 359  2022   Jan              NaN          427.00          276.62
#
#      Inflation_rate  Price_wheat_ton_infl  Price_rice_ton_infl  \
# 0             89.59                322.53               527.53
# ...

# %%
wheat_df = df[["Year", "Month", "Price_wheat_ton", "Inflation_rate", "Price_wheat_ton_infl", "Period"]]

rice_df = df[["Year", "Month", "Price_rice_ton", "Inflation_rate", "Price_rice_ton_infl", "Period"]]

corn_df = df[["Year", "Month", "Price_corn_ton", "Inflation_rate", "Price_corn_ton_infl", "Period"]]

# %%
x_axis = df["Period"]
y_axis = df["Price_wheat_ton"]

# %%
graph = plt.plot(x_axis, y_axis)

# %%
# importing the required module
import matplotlib.pyplot as plt
 
# x axis values
x = ['janeiro','feve','março']
# corresponding y axis values
y = [2,4,1]
 
# plotting the points
plt.plot(x, y)
 
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
 
# giving a title to my graph
plt.title('My first graph!')
 
# function to show the plot
plt.show()
